# %% [markdown]
# ---
#
#
# Nama     : Sintia Sari
#
# NIM      : 0110222135
#
# Angkatan : 2022
#
#
# ---

# %% [markdown]
# # Praktikum di Kelas

# %%
# Import library
import pandas as pd

# %%
# Memanggil file di dalam Google Drive
from google.colab import drive
drive.mount('/content/gdrive')
import os

# Inisiasi directory tempat data akan dibaca dan disimpan
path = "gdrive/MyDrive/Machine Learning/Praktikum/Praktikum01/Data/"

# Menampilkan 5 baris data dalam dataset
df = pd.read_csv(path + 'day.csv')
df.head()
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# ...

# %% [markdown]
# # Praktikum Mandiri

# %% [markdown]
# #### 1. Memuat, membaca, dan menampilkan dataset hour.csv

# %%
# Menampilkan 5 baris data dalam dataset
df_h = pd.read_csv(path + 'hour.csv')
df_h.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# #### 2. Membuat dataframe baru yang diambil adalah instant, dteday,session,temp,hum windspeed

# %%
# Buat dataframe baru dengan kolom yang dipilih
df1 = df_h[['instant', 'dteday', 'season', 'temp', 'hum', 'windspeed']]

# %% [markdown]
# #### 3. Mencetak dataframe baru kelayar

# %%
# Tampilkan 5 data teratas
df1.head()
# Out:
#    instant      dteday  season  temp   hum  windspeed
# 0        1  2011-01-01       1  0.24  0.81        0.0
# 1        2  2011-01-01       1  0.22  0.80        0.0
# 2        3  2011-01-01       1  0.22  0.80        0.0
# 3        4  2011-01-01       1  0.24  0.75        0.0
# 4        5  2011-01-01       1  0.24  0.75        0.0

# %% [markdown]
# #### 4. Menyimpan dataframe ke file csv baru ke direktori data dengan nama latihan01.csv

# %%
# Menentukan direktori tujuan
save_path = "/content/gdrive/MyDrive/Machine Learning/Praktikum/Praktikum01/Data/latihan01.csv"


# Menyimpan dataframe ke CSV
df1.to_csv(save_path, index=False)

print(f"Dataframe berhasil disimpan di: {save_path}")
# Out:
# Dataframe berhasil disimpan di: /content/gdrive/MyDrive/Machine Learning/Praktikum/Praktikum01/Data/latihan01.csv
